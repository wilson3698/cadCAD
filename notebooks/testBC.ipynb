# %%
from engine import run
import matplotlib.pyplot as plt
import numpy as np
import warnings

# %matplotlib inline

# %%
present=False
if present:
    warnings.filterwarnings('ignore')

# %%
d=run.main()
# Out:
# Test

# %%
names = d.keys()[:4]
for n in names:
    d[n]=d[n].apply(float)

# %%
d.columns
# Out:
# Index(['Belief', 'Pool', 'Price', 'Supply', 'mech_step', 'time_step',
#        'timestamp'],
#       dtype='object')

# %%
d.plot(x='time_step', y=['Pool', 'Supply'], figsize=(15,10))
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
d.plot(x='time_step', y=['Pool', 'Supply'], figsize=(15,10), logy=True)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
d["invar"]=(d.Pool/d.Supply)

# %%
d.invar.describe()
# Out:
# count    2001.0
# mean        2.0
# std         0.0
# min         2.0
# 25%         2.0
# 50%         2.0
# 75%         2.0
# max         2.0
# Name: invar, dtype: float64

# %%
d.plot(x='time_step',y=["Price", "Belief", 'invar'] ,figsize=(15,10))
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
d.describe()
